# %% [markdown]
# # Assignment 1
# ## Topic: Familiar with google colab environment and executing some basic Python exercise

# %% [markdown]
# ### Question 1
# Reverse a string

# %%
s = input("Enter string: ")
print("Reversed string:", s[::-1])
# Out:
# Enter string:  Alokparna Mitra
# Reversed string: artiM anrapkolA

# %% [markdown]
# ### Question 2
# Concatenate two strings.

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")
print("Concatenated string:", s1 + s2)
# Out:
# Enter first string:  Alokparna
# Enter second string:   Mitra
# Concatenated string: Alokparna Mitra

# %% [markdown]
# ### Question 3
# Sorting of an array

# %%
arr = list(map(int, input("Enter numbers: ").split()))
arr.sort()
print("Sorted array:", arr)
# Out:
# Enter numbers:  215
# Sorted array: [215]

# %% [markdown]
# ### Question 4
# Print maximum and minimum number

# %%
arr = list(map(int, input("Enter numbers: ").split()))
print("Maximum:", max(arr))
print("Minimum:", min(arr))
# Out:
# Enter numbers:  279
# Maximum: 279
# Minimum: 279

# %% [markdown]
# ### Question 5
# Factorial of a number

# %%
n = int(input("Enter number: "))
fact = 1
for i in range(1, n+1):
    fact *= i
print("Factorial:", fact)
# Out:
# Enter number:  21
# Factorial: 51090942171709440000

# %% [markdown]
# ### Question 6
# Check whether a number is prime or not.

# %%
n = int(input("Enter number: "))
if n > 1:
    for i in range(2, n):
        if n % i == 0:
            print("Not Prime")
            break
    else:
        print("Prime")
else:
    print("Not Prime")
# Out:
# Enter number:  79
# Prime

# %% [markdown]
# ### Question 7
# Print the below
# ```
#    *
#   * *
#  * * *
# * * * *
# ```

# %%
n = int(input("Enter number of rows: "))
for i in range(1, n + 1):
    print(" " * (n - i) + "* " * i)
# Out:
# Enter number of rows:  5
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
